# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('max_columns', 200)

# %%
df = pd.read_csv('Financial Sample.csv')

# %%
df
# Out:
#               Segment                   Country     Product   Discount Band
# 0          Government                    Canada   Carretera            None   \
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df.shape
# Out:
# (700, 16)

# %%
df.head(20)
# Out:
#              Segment                   Country     Product   Discount Band
# 0         Government                    Canada   Carretera            None   \
# 1         Government                   Germany   Carretera            None
# 2          Midmarket                    France   Carretera            None
# 3          Midmarket                   Germany   Carretera            None
# 4          Midmarket                    Mexico   Carretera            None
# 5         Government                   Germany   Carretera            None
# 6          Midmarket                   Germany     Montana            None
# 7   Channel Partners                    Canada     Montana            None
# 8         Government                    France     Montana            None
# 9   Channel Partners                   Germany     Montana            None
# 10         Midmarket                    Mexico     Montana            None
# ...

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Segment                   object
# Country                   object
#  Product                  object
#  Discount Band            object
# Units Sold               float64
#  Manufacturing Price     float64
#  Sale Price              float64
#  Gross Sales             float64
#  Discounts                object
#   Sales                  float64
#  COGS                    float64
#  Profit                   object
# Date                      object
# Month Number               int64
#  Month Name               object
# Year                       int64
# dtype: object

# %%
df.describe()
# Out:
#         Units Sold   Manufacturing Price    Sale Price    Gross Sales
# count   700.000000             700.000000    700.000000   7.000000e+02  \
# mean   1608.294286              96.477143    118.428571   1.827594e+05
# std     867.427859             108.602612    136.775515   2.542623e+05
# min     200.000000               3.000000      7.000000   1.799000e+03
# 25%     905.000000               5.000000     12.000000   1.739175e+04
# 50%    1542.500000              10.000000     20.000000   3.798000e+04
# 75%    2229.125000             250.000000    300.000000   2.790250e+05
# max    4492.500000             260.000000    350.000000   1.207500e+06
#
#              Sales           COGS   Month Number         Year
# count  7.000000e+02     700.000000    700.000000   700.000000
# mean   1.696091e+05  145475.211429      7.900000  2013.750000
# std    2.367263e+05  203865.506118      3.377321     0.433322
# min    1.655080e+03     918.000000      1.000000  2013.000000
# ...

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df.isna().head(20)
# Out:
#     Segment  Country   Product    Discount Band   Units Sold
# 0     False    False      False            False       False  \
# 1     False    False      False            False       False
# 2     False    False      False            False       False
# 3     False    False      False            False       False
# 4     False    False      False            False       False
# 5     False    False      False            False       False
# 6     False    False      False            False       False
# 7     False    False      False            False       False
# 8     False    False      False            False       False
# 9     False    False      False            False       False
# 10    False    False      False            False       False
# 11    False    False      False            False       False
# 12    False    False      False            False       False
# 13    False    False      False            False       False
# ...

# %%
df.isna().sum()
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
# Units Sold               0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
#  Discounts               0
#   Sales                  0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
df.duplicated().head(25)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# dtype: bool

# %%
df.query('Country == "Canada"').sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of               Segment Country     Product   Discount Band   Units Sold
# 0          Government  Canada   Carretera            None       1618.5  \
# 7    Channel Partners  Canada     Montana            None       2518.0
# 11         Enterprise  Canada     Montana            None       2665.5
# 14         Enterprise  Canada     Montana            None        345.0
# 16         Government  Canada       Paseo            None        292.0
# ..                ...     ...          ...             ...         ...
# 671         Midmarket  Canada       Paseo            High       1614.0
# 674         Midmarket  Canada       Paseo            High       2559.0
# 688        Government  Canada         VTT            High        865.5
# 692        Enterprise  Canada         VTT            High       2954.0
# 698        Government  Canada       Paseo            High        723.0
#
# ...

# %%
df
# Out:
#               Segment                   Country     Product   Discount Band
# 0          Government                    Canada   Carretera            None   \
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
ax = df['Year'].value_counts() \
  .plot(kind='bar', title = 'Year of Sales')
ax.set_xlabel('Year')
ax.set_ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %%
df
# Out:
#               Segment                   Country     Product   Discount Band
# 0          Government                    Canada   Carretera            None   \
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df.dtypes
# Out:
# Segment                   object
# Country                   object
#  Product                  object
#  Discount Band            object
# Units Sold               float64
#  Manufacturing Price     float64
#  Sale Price              float64
#  Gross Sales             float64
#  Discounts                object
#   Sales                  float64
#  COGS                    float64
#  Profit                   object
# Date                      object
# Month Number               int64
#  Month Name               object
# Year                       int64
# dtype: object

# %%
df
# Out:
#               Segment                   Country     Product   Discount Band
# 0          Government                    Canada   Carretera            None   \
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df.plot(kind='scatter', x = 'Country', y = '  Sales ',
title = 'Country Vs Sales')
# Out:
# <Axes: title={'center': 'Country Vs Sales'}, xlabel='Country', ylabel='  Sales '>

# %%
df.plot(kind='scatter', x = 'Year', y = ' Product ',
title = 'Year Vs Product')
plt.show()

# %%
df.plot(kind='scatter', x = 'Year', y = '  Sales ',
title = 'Country Vs Sales')
plt.show()

# %%
df.plot(kind='scatter', x = ' Profit ', y = ' Product ',
title = 'Product Vs Discount')
plt.show()

# %%
sns.scatterplot(x = 'Country', y = ' Product ',hue = 'Year', data = df)
# Out:
# <Axes: xlabel='Country', ylabel=' Product '>

# %%
sns.scatterplot(x = 'Country', y = ' Product ',hue = ' Month Name ', data = df)
# Out:
# <Axes: xlabel='Country', ylabel=' Product '>

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
SALES_OF_YEAR=df['Year'].value_counts()
sns.barplot(x=SALES_OF_YEAR.index,y=SALES_OF_YEAR.values)
plt.xlabel('YEAR')
plt.ylabel('SALES')
plt.title('SALES OF YEAR')
plt.show()

# %%
x=(df[' Product '])
y=(df['  Sales '])
plt.bar(x,y)
plt.xlabel(' Product ')
plt.ylabel('sales')
plt.title('Product Sales')
plt.show()

# %%
sns.scatterplot(x = '  Sales ', y = ' Month Name ',hue = ' Month Name ', data = df)
# Out:
# <Axes: xlabel='  Sales ', ylabel=' Month Name '>

# %%
x=(df[' Month Name '])
y=(df['  Sales '])
plt.bar(x,y)
plt.xlabel(' Month Name ')
plt.ylabel('Sales')
plt.title(' Month wise Sales')
plt.show()

# %%
x=(df[' Product '])
y=(df['Units Sold'])
plt.bar(x,y)
plt.xlabel(' Product ')
plt.ylabel('Units Sold')
plt.title('Product wise Units Sold')
plt.show()
